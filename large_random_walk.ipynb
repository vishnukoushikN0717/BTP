# %% [markdown]
# # Applying MC and n-step TD to a 1000 State Random Walk

# %%
from large_random_walk import LargeRandomWalk

# %% [markdown]
# ### Initialize Objects

# %%
import scipy
print(scipy.__version__)
MC = LargeRandomWalk(n_steps=1000, alpha=2e-5, seed = 0)
TD_1_step = LargeRandomWalk(n_steps=1, alpha=.01, seed = 0)
TD_4_step = LargeRandomWalk(n_steps=4, alpha=.01, seed = 0)
# Out:
# 1.14.1

# %% [markdown]
# ## Plot the True Distribution over states
#
# This is solved with a linear system.

# %%
MC.plot_true_mu_s()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Run MC on 100K examples

# %%
MC.run(100000)
# Out:
# 100%|██████████| 100000/100000 [00:21<00:00, 4641.19it/s]

# %% [markdown]
# ## Plot True vs Estimated values for MC

# %%
MC.plot_true_vs_est()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Run TD with 10K examples
#
# It's a faster learning, so we can process less.

# %%
TD_1_step.run(10000)
TD_1_step.plot_true_vs_est()
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 5178.69it/s]
# alt.LayerChart(...)

# %%
TD_4_step.run(10000)
TD_4_step.plot_true_vs_est()
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 5073.25it/s]
# alt.LayerChart(...)
